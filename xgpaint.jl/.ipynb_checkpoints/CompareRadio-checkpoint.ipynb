# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# %config InlineBackend.figure_format = 'retina'

import numpy as np
import matplotlib.pyplot as plt
import healpy as hp
import astropy.units as u
from astropy.cosmology import WMAP9 as cosmo
from astropy.cosmology import z_at_value
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %env OMP_NUM_THREADS=20
# Out:
# env: OMP_NUM_THREADS=20

# %%
def bin_ps(y, nb=1000):
    x = np.arange(len(y))
    bins = np.arange(0, len(y), nb)
    inds = np.digitize(x, bins)
    
    bx = np.array([ np.mean(x[inds==i]) for i in range(2,np.max(inds))])
    by = np.array([ np.mean(y[inds==i]) for i in range(2,np.max(inds))])
    return bx, by

# %%
map_fac = 1

# %%
freq_str = ['30.0', '93.0', '145.0', '217.0', '280.0', '353.0']
freqs = [float(f) for f in freq_str]

conv_freq = [ 0.03701396034733168,
 0.004683509698460815,
 0.002595203002861245,
 0.0020683915234002374,
 0.002331542380044927, 
 0.0033735887524933045]
maps = [hp.read_map(f'/tigress/zequnl/xgpaint/radio_{freq_str[i]}.fits', verbose=False) 
        for i in range(len(freqs))]

# %%
# sehgal_freq_str = ['030', '093', '145', '217', '280', '353']
# sehgal_maps = [hp.read_map(
#     f'/tigress/zequnl/xgpaint/sehgal_colin/{freq}_rad_pts_healpix_nopell_Nside4096_DeltaT_uK_fluxcut148_7mJy_lininterp.fits', verbose=False)
#               for freq in sehgal_freq_str]

# %%
sehgal_freq_str = ['030', '090', '148', '219', '277', '350']
sehgal_maps = [hp.read_map(
    f'/tigress/zequnl/xgpaint/sehgal/{freq}_rad_pts_healpix.fits', verbose=False)
              for freq in sehgal_freq_str]

# %%
plt.figure(figsize=(12, 5))
plt.hist( np.log10(sehgal_maps[3]+1), histtype="step", label="sehgal", bins=50)
plt.hist( np.log10(maps[3]+1), histtype="step", label="zack", bins=50)
plt.yscale("log")

plt.legend()
plt.xlabel(r"$\log_{10}$ pixel flux in Jy/sr (150 GHz)")
# Out:
# Text(0.5, 0, '$\\log_{10}$ pixel flux in Jy/sr (150 GHz)')

# %%
fig, axes = plt.subplots(len(freq_str),1,figsize=(5,12))
for i in range(len(freq_str)):
    
    axes[i].hist( np.log10(sehgal_maps[i] + 1e0), bins=30, histtype="step")
    axes[i].hist( np.log10(maps[i] + 1e0), bins=30, histtype="step")

    axes[i].set_yscale("log")

# %%
def clip_map(m):
#     return m

    m2 = m.copy()
#     m2[m < 1e2] = 0.0
    m2[m > 1e6] = 0.0
    return m2

# %%
ps_auto = [hp.anafast(clip_map(m1), iter=0) for m1 in maps]
sehgal_ps_autos = [hp.anafast(clip_map(m1), iter=0) for m1 in sehgal_maps]

# %%
for i in range(len(ps_auto)):
    plt.figure()
    plt.title(freq_str[i])
    plt.plot(sehgal_ps_autos[i][100:])
    plt.plot(ps_auto[i][100:], alpha=0.1)

# %%
plt.scatter( freqs, [np.mean(ps[500:]) for ps in ps_auto], label='websky' )
plt.scatter( freqs, [np.mean(ps[500:]) for ps in sehgal_ps_autos], marker='X', label='sehgal', lw=0.5, s=50, color='r', alpha=0.5 )

plt.legend()
plt.xlabel('GHz')
plt.ylabel(r'$\langle C_{\ell} \rangle_{\ell}$ for $\ell > 500$')
plt.yscale('log')

plt.yscale('log')
# plt.ylim(1e-31, 1e-23)

# %%
x = [np.mean(ps[500:]) for ps in ps_auto]
y = [np.mean(ps[500:]) for ps in sehgal_ps_autos]
plt.plot( freqs, np.array(x) / np.array(y))
plt.ylim(0.5, 1.5)
plt.xlabel("freqs")
plt.ylabel(r"websky / sehgal $\langle C_{\ell} \rangle$")
# Out:
# Text(0, 0.5, 'websky / sehgal $\\langle C_{\\ell} \\rangle$')

# %%
# freq_str = ['30.0', '143.0', '217.0', '353.0']
# freqs = [float(f) for f in freq_str]
# stoch_maps = [hp.read_map(f'/tigress/zequnl/xgpaint/radio_stoch_{fr}.fits', verbose=False) * map_fac_stoch
#         for fr in freq_str]
# stoch_ps_auto = [hp.anafast(m1, iter=0) for m1 in stoch_maps]
# stoch_monos = [ps_[0] for ps_ in stoch_ps_auto]

# %%
# plt.scatter( freqs, monos, label='xgpaint.jl' )
# plt.scatter( freqs, sehgal_monos, marker='X', label='sehgal', lw=0.5, s=50, color='r', alpha=0.5 )
# plt.scatter( freqs, stoch_monos, marker='v', label='stochastic $a_i$', lw=0.5, s=50, color='g', alpha=0.5 )

# plt.legend()
# plt.xlabel('GHz')
# plt.ylabel('monopole')
# plt.yscale('log')

# plt.yscale('log')
# # plt.ylim(1e-31, 1e-23)
