# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# %config InlineBackend.figure_format = 'retina'
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.plot()
plt.xlabel("This is a test! $ \Lambda \gamma $")
# Out:
# Text(0.5, 0, 'This is a test! $ \\Lambda \\gamma $')
